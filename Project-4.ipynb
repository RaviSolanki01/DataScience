# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
emp = pd.read_csv('Downloads/empl.csv')

# %%
emp
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0        NaN  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0        NaN  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0        NaN  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
sns.heatmap(emp.isnull())

# %%
emp[emp['Country']== 'America']
# Out:
#     SNo    Name   Age     City  Country   Salary
# 4     5   kamal  30.0      NaN  America      NaN
# 6     7  Steven  43.0  BayArea  America   8300.0
# 8     9    hari  50.0  newyork  America  67666.0
# 9    11    yami   NaN  newyork  America   8888.0
# 11   13   kamal  30.0      NaN  America  34344.0
# 13   15  Steven  43.0      NaN  America   8300.0
# 15   17    hari   NaN  newyork  America  67666.0
# 16   18    yami  27.0  newyork  America   8888.0

# %%
# as 'newyork' is most frequent in 'America' , replaced NaN(America) with 'newyork'
emp['City']  = emp['City'].replace(np.NaN,'newyork')
emp
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 4     5   kamal  30.0    newyork  America      NaN
# 5     6    Geet   NaN   HongKong     Asia  30007.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 9    11    yami   NaN    newyork  America   8888.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0    newyork  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0    newyork  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 15   17    hari   NaN    newyork  America  67666.0
# 16   18    yami  27.0    newyork  America   8888.0
# ...

# %%
emp.dropna(axis=0,inplace=True)

# %%
sns.regplot(x=emp['Age'],y=emp['Salary'],data=emp)
# Out:
# /home/direwolf/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.heatmap(emp.isnull())

# %%
#emp  = empSal.iloc[:,2:]

# %%
emp
# Out:
#     SNo    Name   Age       City  Country   Salary
# 0     1     Tom  28.0    Toronto   Canada  20000.0
# 1     2     Lee  31.0    Edmonto   Canada   3900.0
# 2     3    Dave  34.0    Toronto   Canada   8000.0
# 3     4    Anik  26.0   HongKong     Asia  66672.0
# 6     7  Steven  43.0    BayArea  America   8300.0
# 7     8     Ram  38.0  Hyderabad     Asia  54666.0
# 8     9    hari  50.0    newyork  America  67666.0
# 10   12    Anik  26.0   HongKong     Asia  66672.0
# 11   13   kamal  30.0    newyork  America  34344.0
# 12   14    Geet  22.0   HongKong     Asia  30007.0
# 13   15  Steven  43.0    newyork  America   8300.0
# 14   16     Ram  38.0  Hyderabad     Asia  54666.0
# 16   18    yami  27.0    newyork  America   8888.0
# 18   20  Andrew  34.0      Congo   Africa  34432.0
# 19   21   soham  32.0     Angola   Africa  34534.0
# 20   22    Grig  26.0    Finland   Europe  33451.0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labEnc = LabelEncoder()

emp['Country'] = labEnc.fit_transform(emp['Country'].astype(str))
emp['City'] = labEnc.fit_transform(emp['City'].astype(str))

# %%
emp
# Out:
#     SNo    Name   Age  City  Country   Salary
# 0     1     Tom  28.0     7        3  20000.0
# 1     2     Lee  31.0     3        3   3900.0
# 2     3    Dave  34.0     7        3   8000.0
# 3     4    Anik  26.0     5        2  66672.0
# 6     7  Steven  43.0     1        1   8300.0
# 7     8     Ram  38.0     6        2  54666.0
# 8     9    hari  50.0     8        1  67666.0
# 10   12    Anik  26.0     5        2  66672.0
# 11   13   kamal  30.0     8        1  34344.0
# 12   14    Geet  22.0     5        2  30007.0
# 13   15  Steven  43.0     8        1   8300.0
# 14   16     Ram  38.0     6        2  54666.0
# 16   18    yami  27.0     8        1   8888.0
# 18   20  Andrew  34.0     2        0  34432.0
# 19   21   soham  32.0     0        0  34534.0
# 20   22    Grig  26.0     4        4  33451.0

# %%
emp = emp.iloc[:,2:]

# %%
emp
# Out:
#      Age  City  Country   Salary
# 0   28.0     7        3  20000.0
# 1   31.0     3        3   3900.0
# 2   34.0     7        3   8000.0
# 3   26.0     5        2  66672.0
# 6   43.0     1        1   8300.0
# 7   38.0     6        2  54666.0
# 8   50.0     8        1  67666.0
# 10  26.0     5        2  66672.0
# 11  30.0     8        1  34344.0
# 12  22.0     5        2  30007.0
# 13  43.0     8        1   8300.0
# 14  38.0     6        2  54666.0
# 16  27.0     8        1   8888.0
# 18  34.0     2        0  34432.0
# 19  32.0     0        0  34534.0
# 20  26.0     4        4  33451.0

# %% [raw]
# #sklearn.impute simpleImputer class works for imputing null in object or categorical data
# from sklearn.impute import SimpleImputer
# sImp  = SimpleImputer(strategy='most_frequent')
# emp['City']=imp.fit_transform(emp['City'].values.reshape(-1,1))

# %%
sns.regplot(x=emp['Age'],y=emp['Salary'],data=emp)
# Out:
# /home/direwolf/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(emp['Salary'])

# %%
sns.boxplot(x=emp['City'],y=emp['Salary'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
X = emp.iloc[:,:-1]

# %%
y = emp.iloc[:,-1]

# %%
y
# Out:
# 0     20000.0
# 1      3900.0
# 2      8000.0
# 3     66672.0
# 6      8300.0
# 7     54666.0
# 8     67666.0
# 10    66672.0
# 11    34344.0
# 12    30007.0
# 13     8300.0
# 14    54666.0
# 16     8888.0
# 18    34432.0
# 19    34534.0
# 20    33451.0
# Name: Salary, dtype: float64

# %%
y.shape
# Out:
# (16,)

# %%
from sklearn.metrics import r2_score

# %%
#function to check r2_score on all posible values
def someNum(num):
    xtrain,xtest,ytrain,ytest= train_test_split(X,y,test_size=.20,random_state=num)
    lm1 = LinearRegression()
    lm1.fit(xtrain,ytrain)
    predictn1  = lm1.predict(xtest)
    s =r2_score(ytest,predictn1)
    if True:#if(0.00 < s ):
        print("=====> "+str(num))
        print(mean_squared_error(ytest,predictn1))
        print(s)
for a in range(0,101):
    someNum(a)#empSal = pd.DataFrame(data=emp)
# Out:
# =====> 0
# 1334093004.069096
# -1.5961806537491992
# =====> 1
# 1161494767.2117462
# -0.9233443128639023
# =====> 2
# 656413559.3171911
# -0.8400222139610962
# =====> 3
# 1435392458.5882435
# -1.2917061702350163
# =====> 4
# 1217175239.2274942
# -0.7130297128159315
# =====> 5
# 866462210.1227262
# -0.12723509118215293
# =====> 6
# 1146737179.6669593
# -0.9145931792821043
# =====> 7
# 805756326.8732696
# -1.1090021469316742
# =====> 8
# 1139797642.5042574
# -0.9254723505469327
# =====> 9
# 559939664.0742962
# -1.5130915935145803
# =====> 10
# 1316628559.3230991
# -6.634599985635128
# =====> 11
# 795750913.2541188
# -0.3036621024489592
# =====> 12
# 151118826.57690948
# -0.6496711621311435
# =====> 13
# 847777632.933438
# -1.0289282239440576
# =====> 14
# 1757034746.6866364
# -1.6045519084566173
# =====> 15
# 973856415.6162941
# -0.7029912642037235
# =====> 16
# 760978952.1756881
# -0.5853545961889992
# =====> 17
# 1036750064.3334565
# -0.4651835002127924
# =====> 18
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.20, random_state=42)

# %%
X_train.shape
# Out:
# (12, 3)

# %%
lm = LinearRegression()

# %%
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lm.coef_ , lm.intercept_ ,lm.score(X_train,y_train)
# Out:
# (array([  -28.10725036,   922.39368915, -2232.82067353]),
#  33456.183177986255,
#  -0.028534509656727103)

# %%
pred  = lm.predict(X_test)

# %%
mean_squared_error(y_test,pred)
# Out:
# 305230044.3142241

# %%
r2_score(y_test,pred)
# Out:
# 0.12683905598982148
